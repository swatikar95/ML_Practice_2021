# %%
import pandas as pd
import numpy as np

from scipy import stats

from mlxtend.preprocessing import minmax_scaling

import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-e25dc0c5be2d> in <module>
#       4 from scipy import stats
#       5
# ----> 6 from mlxtend.preprocessing import minmax_scaling
#       7
#       8 import seaborn as sns
#
# ModuleNotFoundError: No module named 'mlxtend'

# %% [markdown]
# In scaling, you're changing the range of your data,

# %%
# generate 1000 data points randomly drawn from an exponential distribution
original_data = np.random.exponential(size=1000)

# mix-max scale the data between 0 and 1
scaled_data = minmax_scaling(original_data, columns=[0])

#plot
fig,ax = plt.subplots(1,2)
sns.displot(original_data,ax=ax[0])
ax[0].set_title("Original Data")
sns.displot(scaled_data,ax=ax[1])
ax[0].set_title("Scaled Data")
# Out:
# /Users/swatikar/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-967facd721af> in <module>
#       8 sns.displot(original_data,ax=ax[0])
#       9 ax[0].set_title("Original Data")
# ---> 10 sns.displot(scaled_data,ax=ax[1])
#      11 ax[0].set_title("Scaled Data")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2147     p = _DistributionFacetPlotter(
#    2148         data=data,
# -> 2149         variables=_DistributionFacetPlotter.get_semantics(locals())
#    2150     )
#    2151
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in __init__(self, data, variables)
#     107     ):
#     108
# --> 109         super().__init__(data=data, variables=variables)
#     110
#     111     @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     661             self.input_format = "wide"
#     662             plot_data, variables = self._assign_variables_wideform(
# --> 663                 data, **variables,
#     664             )
#     665         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/_core.py in _assign_variables_wideform(self, data, **kwargs)
#     712
#     713         # Determine if the data object actually has any data in it
# --> 714         empty = data is None or not len(data)
#     715
#     716         # Then, determine if we have "flat" data (a single vector)
#
# TypeError: object of type 'MinMaxScaler' has no len()

# %%
# normalize the exponential data with boxcox
original_data = np.random.exponential(size=1000)
normalized_data = stats.boxcox(original_data)

# plot both together to compare
fig, ax=plt.subplots(1,2)
sns.distplot(original_data, ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(normalized_data[0], ax=ax[1])
ax[1].set_title("Normalized data")
# Out:
# /Users/swatikar/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/swatikar/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Normalized data')
